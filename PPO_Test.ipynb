# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonali2824/RL-PROJECT/blob/main/PPO_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
folder = '/content/drive/MyDrive/PPO'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import numpy as np
import time
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

class ActorNetwork(nn.Module):
    def __init__(self, obs_shape, action_shape):
        super(ActorNetwork, self).__init__()
        self.fc1 = nn.Linear(obs_shape[0]*obs_shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, action_shape)
        
    def forward(self, x):
        if isinstance(x, np.ndarray):
            x = torch.tensor(x, dtype=torch.float)
        x = x.view(1, 105)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=-1)
        dist = torch.distributions.Categorical(logits=x)
        return dist

class CriticNetwork(nn.Module):
    def __init__(self, obs_shape):
        super(CriticNetwork, self).__init__()
        self.fc1 = nn.Linear(obs_shape[0]*obs_shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)
        
    def forward(self, x):
        if isinstance(x, np.ndarray):
            x = torch.tensor(x, dtype=torch.float)
        #x = x.view(x.size(0), -1)
        x = x.view(1, 105)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


    
#PPO 
class PPO:
    def __init__(self, env):
        self.env=env
        self.obs_dimension=self.env.observation_space.shape
        self.act_dimension=self.env.action_space.n

        #actor critic network
        self.actor=ActorNetwork(self.obs_dimension, self.act_dimension)
        self.critic=CriticNetwork(self.obs_dimension)
        self.lr = 0.005

        # Initialize optimizers for actor and critic
        self.actor_optimizer = Adam(self.actor.parameters(), lr=self.lr, eps=1e-5)  
        self.critic_optimizer = Adam(self.critic.parameters(), lr=self.lr,eps=1e-5)
        self.learn_rewards = []

        self.logger = {
			'delta_t': time.time_ns(),
			't_so_far': 0,          # timesteps so far
			'i_so_far': 0,          # iterations so far
			'batch_lens': [],       # episodic lengths in batch
			'batch_rews': [],       # episodic returns in batch
			'actor_losses': [],     # losses of actor network in current iteration
		}
        self.learn(1000000)
        plt.plot(self.learn_rewards)
        plt.show()

    def learn(self, total_timesteps):
        self.overall_rewards = []
        self.timesteps_per_batch = 4800                 # Number of timesteps to run per batch
        self.max_timesteps_per_episode = 1600           # Max number of timesteps per episode
        self.n_updates_per_iteration = 5                # Number of times to update actor/critic per iteration
        self.lr = 0.005                                 # Learning rate of actor optimizer
        self.gamma = 0.95                               # Discount factor to be applied when calculating Rewards-To-Go
        self.clip = 0.2                                 # Recommended 0.2, helps define the threshold to clip the ratio during SGA

        # Miscellaneous parameters
        self.render = False                              # If we should render during rollout
        self.render_every_i = 10                        # Only render every n iterations
        self.save_freq = 10                             # How often we save in number of iterations
        self.seed = None                                # Sets the seed of our program, used for reproducibility of results
        print(f"Learning... Running {self.max_timesteps_per_episode} timesteps per episode, ", end='')
        print(f"{self.timesteps_per_batch} timesteps per batch for a total of {total_timesteps} timesteps")
        t_so_far = 0 # Timesteps simulated so far
        i_so_far = 0 # Iterations ran so far
        maxreward = []
        while t_so_far < total_timesteps:                                                                       # ALG STEP 2
            # Autobots, roll out (just kidding, we're collecting our batch simulations here)
            batch_obs, batch_acts, batch_log_probs, batch_rtgs, batch_lens = self.rollout()                     # ALG STEP 3
            maxreward.append(max(batch_rtgs))
            print("max")
            if(len(maxreward)>5):
                plt.plot(maxreward)
                plt.savefig(folder+'\episode_reward'+str(len(maxreward))+'.jpg')
                plt.close()

            # Calculate how many timesteps we collected this batch
            t_so_far += np.sum(batch_lens)

            # Increment the number of iterations
            i_so_far += 1

            # Logging timesteps so far and iterations so far
            self.logger['t_so_far'] = t_so_far
            self.logger['i_so_far'] = i_so_far

            # Calculate advantage at k-th iteration
            log_prob, V, entropy= self.evaluate(batch_obs, batch_acts)
            A_k = batch_rtgs - V.detach()                                                                       # ALG STEP 5
            A_k = (A_k - A_k.mean()) / (A_k.std() + 1e-10)
            
            # This is the loop where we update our network for some n epochs
            for _ in range(self.n_updates_per_iteration):                                                       # ALG STEP 6 & 7
                # Calculate V_phi and pi_theta(a_t | s_t)
                curr_log_probs, V, curr_entropy = self.evaluate(batch_obs, batch_acts)

                ratios = torch.exp(curr_log_probs - batch_log_probs)
                ratios.requires_grad = True
                A_k.requires_grad = True
                # Calculate surrogate losses.
                surr1 = ratios * A_k
                surr2 = torch.clamp(ratios, 1 - self.clip, 1 + self.clip) * A_k

                actor_loss = (-torch.min(surr1, surr2)).mean()
                critic_loss = nn.MSELoss()(V, batch_rtgs)

                # Calculate gradients and perform backward propagation for actor network
                self.actor_optimizer.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.actor_optimizer.step()

                # Calculate gradients and perform backward propagation for critic network
                self.critic_optimizer.zero_grad()
                critic_loss.backward()
                self.critic_optimizer.step()

                # Log actor loss
                self.logger['actor_losses'].append(actor_loss.detach())

            # Print a summary of our training so far
            # self._log_summary()
            print("End!")

            # Save our model if it's time
            # if i_so_far % self.save_freq == 0:
            print("path", folder+'/ppo_actor.pth')
            torch.save(self.actor.state_dict(), folder+'/ppo_actor.pth')
            torch.save(self.critic.state_dict(), folder+'/ppo_critic.pth')
            self.learn_rewards.append(np.mean(self.overall_rewards))
            print("Plot", self.overall_rewards)
            # plt.plot(self.overall_rewards)
            # plt.show()



    def rollout(self):
		
        # Batch data. For more details, check function header.
        batch_obs = []
        batch_acts = []
        batch_log_probs = []
        batch_rews = []
        batch_rtgs = []
        batch_lens = []

        # Episodic data. Keeps track of rewards per episode, will get cleared
        # upon each new episode
        ep_rews = []

        t = 0 # Keeps track of how many timesteps we've run so far this batch

        # Keep simulating until we've run more than or equal to specified timesteps per batch
        while t < self.timesteps_per_batch:
            ep_rews = [] # rewards collected per episode

            # Reset the environment. sNote that obs is short for observation. 
            obs, info = self.env.reset()
            done = truncated = False

            # Run an episode for a maximum of max_timesteps_per_episode timesteps
            for ep_t in range(self.max_timesteps_per_episode):
                # If render is specified, render the environment
                # if self.render and (self.logger['i_so_far'] % self.render_every_i == 0):# and len(batch_lens) == 0:
                #     self.env.render()

                t += 1 # Increment timesteps ran this batch so far

                # Track observations in this batch
                batch_obs.append(obs)

                # Calculate action and make a step in the env. 
                # Note that rew is short for reward.
                action, log_prob = self.get_action(obs)
                #print("Action and log_prob", action, log_prob)
                obs, rew, done, truncated, info = self.env.step(action)
                # Track recent reward, action, and action log probability
                ep_rews.append(rew)
                batch_acts.append(action)
                batch_log_probs.append(log_prob)

                # If the environment tells us the episode is terminated, break
                if done or info["crashed"]:
                    break

            # Track episodic lengths and rewards
            batch_lens.append(ep_t + 1)
            batch_rews.append(ep_rews)
            self.overall_rewards.append(np.mean(ep_rews))

        # Reshape data as tensors in the shape specified in function description, before returning
        batch_obs = torch.tensor(batch_obs, dtype=torch.float)
        batch_acts = torch.tensor(batch_acts, dtype=torch.float)
        batch_log_probs = torch.tensor(batch_log_probs, dtype=torch.float)
        batch_rtgs = self.compute_rtgs(batch_rews)                                                              # ALG STEP 4

        # Log the episodic returns and episodic lengths in this batch.
        # self.logger['batch_rews'] = batch_rews
        # self.logger['batch_lens'] = batch_lens

        return batch_obs, batch_acts, batch_log_probs, batch_rtgs, batch_lens
    

    def get_action(self, obs):
        with torch.no_grad():
            dist = self.actor(obs)
            action = dist.sample()
            log_prob = dist.log_prob(action)
        return action.item(), log_prob
    
    def evaluate(self, obs, action):
        obs = obs.view(obs.size()[0] * obs.size()[1], obs.size()[2])[:obs.size()[1],:]
        with torch.no_grad():
            dist = self.actor(obs)
            log_prob = dist.log_prob(action)
        value = self.critic(obs)
        entropy = dist.entropy()
        return log_prob, value, entropy

    def compute_rtgs(self, batch_rews):
        """
            Compute the Reward-To-Go of each timestep in a batch given the rewards.

            Parameters:
                batch_rews - the rewards in a batch, Shape: (number of episodes, number of timesteps per episode)

            Return:
                batch_rtgs - the rewards to go, Shape: (number of timesteps in batch)
        """
        # The rewards-to-go (rtg) per episode per batch to return.
        # The shape will be (num timesteps per episode)
        batch_rtgs = []

        # Iterate through each episode
        for ep_rews in reversed(batch_rews):

            discounted_reward = 0 # The discounted reward so far

            # Iterate through all rewards in the episode. We go backwards for smoother calculation of each
            # discounted return (think about why it would be harder starting from the beginning)
            for rew in reversed(ep_rews):
                discounted_reward = rew + discounted_reward * self.gamma
                batch_rtgs.insert(0, discounted_reward)

        # Convert the rewards-to-go into a tensor
        batch_rtgs = torch.tensor(batch_rtgs, dtype=torch.float)

        return batch_rtgs

# %%
# Environment
# !pip install gymnasium
import gymnasium as gym
# !pip install git+https://github.com/eleurent/highway-env#egg=highway-env
import highway_env
highway_env.register_highway_envs()

# Agent
# !pip install git+https://github.com/eleurent/rl-agents#egg=rl-agents

# Visualisation utils
# !pip install moviepy
# !pip install imageio_ffmpeg
import sys
# %load_ext tensorboard
# !pip install tensorboardx gym pyvirtualdisplay
# !apt-get install -y xvfb python-opengl ffmpeg
# !git clone https://github.com/eleurent/highway-env.git 2> /dev/null
sys.path.insert(0, '/content/highway-env/scripts/')
from utils import show_videos
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium) (6.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium) (1.22.4)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium) (2.2.1)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.8.0->gymnasium) (3.15.0)
# Installing collected packages: farama-notifications, jax-jumpy, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting highway-env
#   Cloning https://github.com/eleurent/highway-env to /tmp/pip-install-08pga8rx/highway-env_026855225eb94dd5ac782f99ba3378cb
#   Running command git clone --filter=blob:none --quiet https://github.com/eleurent/highway-env /tmp/pip-install-08pga8rx/highway-env_026855225eb94dd5ac782f99ba3378cb
#   Resolved https://github.com/eleurent/highway-env to commit d7a95ddf5d438e378004a9df86d9d9739c0db7c8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium>=0.27 in /usr/local/lib/python3.9/dist-packages (from highway-env) (0.28.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from highway-env) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from highway-env) (1.22.4)
# Requirement already satisfied: pygame>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from highway-env) (2.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from highway-env) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from highway-env) (3.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from gymnasium>=0.27->highway-env) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium>=0.27->highway-env) (4.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium>=0.27->highway-env) (2.2.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium>=0.27->highway-env) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium>=0.27->highway-env) (6.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->highway-env) (8.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->highway-env) (2022.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.8.0->gymnasium>=0.27->highway-env) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->highway-env) (1.16.0)
# Building wheels for collected packages: highway-env
#   Building wheel for highway-env (pyproject.toml) ... done
#   Created wheel for highway-env: filename=highway_env-1.8.1-py3-none-any.whl size=103792 sha256=34ed8858444501d691d0284eb5216c1fc47c750b136b8ce8615cb76521c93d9a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jhyog2fz/wheels/24/34/ed/b4b2707e60527327929c9aea45f912af3c7ad8ecbb84f12a57
# Successfully built highway-env
# Installing collected packages: highway-env
# Successfully installed highway-env-1.8.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rl-agents
#   Cloning https://github.com/eleurent/rl-agents to /tmp/pip-install-nevp3pof/rl-agents_69e34755f106475a863b6db5f0a4d6c4
#   Running command git clone --filter=blob:none --quiet https://github.com/eleurent/rl-agents /tmp/pip-install-nevp3pof/rl-agents_69e34755f106475a863b6db5f0a4d6c4
#   Resolved https://github.com/eleurent/rl-agents to commit cff61d5c2e166b3479647633aae4a2f65d9551d8
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.9/dist-packages (from rl-agents) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rl-agents) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from rl-agents) (1.5.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from rl-agents) (0.56.4)
# Requirement already satisfied: pygame in /usr/local/lib/python3.9/dist-packages (from rl-agents) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from rl-agents) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from rl-agents) (0.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from rl-agents) (1.16.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from rl-agents) (2.0.0+cu118)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from rl-agents) (1.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.2.0->rl-agents) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.2.0->rl-agents) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.2.0->rl-agents) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.2.0->rl-agents) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.2.0->rl-agents) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.2.0->rl-agents) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.2.0->rl-agents) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.2.0->rl-agents) (16.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium->rl-agents) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium->rl-agents) (6.3.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from gymnasium->rl-agents) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from gymnasium->rl-agents) (0.0.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->rl-agents) (8.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->rl-agents) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->rl-agents) (67.6.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->rl-agents) (2022.7.1)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from tensorboardX->rl-agents) (3.20.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.8.0->gymnasium->rl-agents) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.2.0->rl-agents) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.2.0->rl-agents) (1.3.0)
# Building wheels for collected packages: rl-agents, docopt
#   Building wheel for rl-agents (setup.py) ... done
#   Created wheel for rl-agents: filename=rl_agents-1.0.dev0-py3-none-any.whl size=112914 sha256=23e73599ad154bc79223fdc3ea05c0b544b0a97cd6f9bd6e12842f676dae1894
#   Stored in directory: /tmp/pip-ephem-wheel-cache-15jvva6n/wheels/2f/4f/9f/3a6fada1ed68d216d372eb0cfce5ce112f52f7f95e2d2dfd64
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=c997e0fe7ff715989b63e33e0d81a7cd92bfcd840e308faadac8dfa421266a6c
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built rl-agents docopt
# Installing collected packages: docopt, tensorboardX, rl-agents
# Successfully installed docopt-0.6.2 rl-agents-1.0.dev0 tensorboardX-2.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: moviepy in /usr/local/lib/python3.9/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.9/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.9/dist-packages (from moviepy) (2.25.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from moviepy) (1.22.4)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.9/dist-packages (from moviepy) (4.65.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from moviepy) (0.4.8)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.9/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from moviepy) (2.27.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.9/dist-packages (from imageio<3.0,>=2.5->moviepy) (8.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.12)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio_ffmpeg in /usr/local/lib/python3.9/dist-packages (0.4.8)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.9/dist-packages (2.6)
# Requirement already satisfied: gym in /usr/local/lib/python3.9/dist-packages (0.25.2)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from tensorboardx) (3.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorboardx) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from tensorboardx) (1.22.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from gym) (6.3.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.8.0->gym) (3.15.0)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   freeglut3 libfontenc1 libpython2-stdlib libxfont2 libxkbfile1 python2
#   python2-minimal x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc
# The following NEW packages will be installed:
#   freeglut3 libfontenc1 libpython2-stdlib libxfont2 libxkbfile1 python-opengl
#   python2 python2-minimal x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 14 newly installed, 0 to remove and 24 not upgraded.
# Need to get 8,318 kB of archives.
# After this operation, 18.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Fetched 8,318 kB in 1s (11.6 MB/s)
# Selecting previously unselected package python2-minimal.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 122378 files and directories currently installed.)
# Preparing to unpack .../00-python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../01-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../02-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../03-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../04-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../05-python-opengl_3.1.0+dfsg-2build1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../06-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../07-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../08-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../09-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../10-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../11-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up python-opengl (3.1.0+dfsg-2build1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
"""
	This file is used only to evaluate our trained policy/actor after
	training in main.py with ppo.py. I wrote this file to demonstrate
	that our trained policy exists independently of our learning algorithm,
	which resides in ppo.py. Thus, we can test our trained policy without 
	relying on ppo.py.
"""
# from PPO import PPO
import matplotlib.pyplot as plt
import numpy as np
def _log_summary(ep_len, ep_ret, ep_num):
		"""
			Print to stdout what we've logged so far in the most recent episode.

			Parameters:
				None

			Return:
				None
		"""
		# Round decimal places for more aesthetic logging messages
		ep_len = str(round(ep_len, 2))
		ep_ret = str(round(ep_ret, 2))

		# Print logging statements
		print(flush=True)
		print(f"-------------------- Episode #{ep_num} --------------------", flush=True)
		print(f"Episodic Length: {ep_len}", flush=True)
		print(f"Episodic Return: {ep_ret}", flush=True)
		print(f"------------------------------------------------------", flush=True)
		print(flush=True)

def rollout(policy, env, render):
	"""
		Returns a generator to roll out each episode given a trained policy and
		environment to test on. 

		Parameters:
			policy - The trained policy to test
			env - The environment to evaluate the policy on
			render - Specifies whether to render or not
		
		Return:
			A generator object rollout, or iterable, which will return the latest
			episodic length and return on each iteration of the generator.

		Note:
			If you're unfamiliar with Python generators, check this out:
				https://wiki.python.org/moin/Generators
			If you're unfamiliar with Python "yield", check this out:
				https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do
	"""
	# Rollout until user kills process
	episode_rewards = []
	#num_episodes = 10000
	agents = 20
	agent_reward = []
	print("Threshold", env.spec)
	for agent in range(agents):
		episode_rewards = []
		num_episodes = 1000
		for i in range(num_episodes):
			obs, info = env.reset()
			done = False

			# number of timesteps so far
			t = 0

			# Logging data
			ep_len = 0            # episodic length
			ep_ret = 0            # episodic return

			while not done:
				t += 1

				# Render environment if specified, off by default
				# if render:
				# 	env.render()

				# Query deterministic action from policy and run it
				#action = PPO.get_action(obs=obs) #policy(obs).detach().numpy()
				dist = policy(obs)
				action = dist.sample()
				#print("Action", action)
				obs, rew, done, _, _ = env.step(action)

				# Sum all episodic rewards as we go along
				ep_ret += rew
			#print("End!")
			# Track episodic length
			ep_len = t
			episode_rewards.append(ep_ret)
			#print("Episode rewards", episode_rewards)
			# returns episodic length and return in this iteration
			yield ep_len, ep_ret
		
		# Calculate performance metrics
		mean_reward = sum(episode_rewards) / num_episodes
		std_reward = np.std(episode_rewards)
		#success_rate = sum(episode_rewards >= env.spec.reward_threshold) / num_episodes

		# Print the results
		print(f"Mean reward per episode: {mean_reward}")
		print(f"Standard deviation of rewards: {std_reward}")
		#print(f"Success rate: {success_rate}")
		agent_reward.append(episode_rewards)
  
		# Plot the final learning curve
		# plt.plot(episode_rewards)
		# plt.xlabel('Episode')
		# plt.ylabel('Reward')
		# plt.title('Learning Curve')
		# plt.show()
		num_agents = len(agent_reward)
		
	# Average Returns Lists
	PPO_learning_average_episode_rewards = []
	for episode in range(0, num_episodes) :
		reward = 0
		for agent in range(0, num_agents) :
			reward += agent_reward[agent][episode]
		PPO_learning_average_episode_rewards.append(reward / num_agents)
	
	plt.plot(range(num_episodes), PPO_learning_average_episode_rewards, label = "PPO-Learning Agent", c = plt.cm.tab20c(0))
	#plt.plot(range(num_episodes), example_q_average_episode_rewards, label = "Example Q-Learning Agent", c = plt.cm.tab20c(4), alpha = 0.75)
	plt.title("Intersection Average Learning Curve\n{} PPO-Learning Agents' Performance Averaged".format(num_agents))
	plt.xlabel("Episodes of Training")
	plt.ylabel("Average Undiscounted Return")
	plt.legend()
	plt.grid()
	plt.show()

def eval_policy(policy, env, render=False):
	"""
		The main function to evaluate our policy with. It will iterate a generator object
		"rollout", which will simulate each episode and return the most recent episode's
		length and return. We can then log it right after. And yes, eval_policy will run
		forever until you kill the process. 

		Parameters:
			policy - The trained policy to test, basically another name for our actor model
			env - The environment to test the policy on
			render - Whether we should render our episodes. False by default.

		Return:
			None

		NOTE: To learn more about generators, look at rollout's function description
	"""
	# Rollout with the policy and environment, and log each episode's data
	for ep_num, (ep_len, ep_ret) in enumerate(rollout(policy, env, render)):
		_log_summary(ep_len=ep_len, ep_ret=ep_ret, ep_num=ep_num)

# %%
# import gymnasium as gym
# import sys
# import torch
# import numpy as np
# import highway_env
# import warnings
# import time
import pprint
# # from PPO import PPO
# # from PPO import ActorNetwork
# from eval_policy import eval_policy
# highway_env.register_highway_envs()

from rl_agents.agents.common.factory import  load_environment

# warnings.filterwarnings('ignore')
def test(env, actor_model):
	"""
		Tests the model.

		Parameters:
			env - the environment to test the policy on
			actor_model - the actor model to load in

		Return:
			None
	"""
	print(f"Testing {actor_model}", flush=True)

	# If the actor model is not specified, then exit
	if actor_model == '':
		print(f"Didn't specify model file. Exiting.", flush=True)
		sys.exit(0)

	# Extract out dimensions of observation and action spaces
	obs_dim = env.observation_space.shape
	act_dim = env.action_space.n

	# Build our policy the same way we build our actor model in PPO
	policy = ActorNetwork(obs_dim, act_dim)
	policy.load_state_dict(torch.load(actor_model))
	print("eval", policy.eval())
	for name, param in policy.state_dict().items():
		if 'weight' in name:
			print(name, param)
	print("Policy", policy)

	# Evaluate our policy with a separate module, eval_policy, to demonstrate
	# that once we are done training the model/policy with ppo.py, we no longer need
	# ppo.py since it only contains the training algorithm. The model/policy itself exists
	# independently as a binary file that can be loaded in with torch.
	eval_policy(policy=policy, env=env, render=True)

env_config = {
    "id": "intersection-v0",
    "import_module": "highway_env",
    "observation": {
        "type": "Kinematics",
        "vehicles_count": 15,
        "features": ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h"],
        "features_range": {
            "x": [-100, 100],
            "y": [-100, 100],
            "vx": [-20, 20],
            "vy": [-20, 20]
        },
        "absolute": True,
        "order": "shuffled"
    },
    "destination":"o1"
}


env = load_environment(env_config)
env.reset()
pprint.pprint(env.config)

def train():
    print("train")
    #retrain
    PPO(env)

#train()
test(env=env, actor_model=folder+"/ppo_actor.pth")
# Out:
# /usr/local/lib/python3.9/dist-packages/gymnasium/envs/registration.py:523: DeprecationWarning: WARN: The environment intersection-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# /usr/local/lib/python3.9/dist-packages/gymnasium/utils/passive_env_checker.py:42: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (15, 7)
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# ------------------------------------------------------
#
#
# -------------------- Episode #22 --------------------
# Episodic Length: 15
# Episodic Return: 5.17
# ------------------------------------------------------
#
#
# -------------------- Episode #23 --------------------
# Episodic Length: 17
# Episodic Return: 6.09
# ------------------------------------------------------
#
#
# -------------------- Episode #24 --------------------
# Episodic Length: 8
# Episodic Return: -4.38
# ------------------------------------------------------
#
#
# -------------------- Episode #25 --------------------
# Episodic Length: 30
# Episodic Return: 4.95
# ------------------------------------------------------
#
#
# -------------------- Episode #26 --------------------
# Episodic Length: 26
# Episodic Return: 3.09
# ------------------------------------------------------
#
#
# -------------------- Episode #27 --------------------
# Episodic Length: 6
# Episodic Return: -2.44
# ------------------------------------------------------
#
#
# -------------------- Episode #28 --------------------
# Episodic Length: 10
# Episodic Return: 5.97
# ------------------------------------------------------
#
#
# -------------------- Episode #29 --------------------
# Episodic Length: 11
# Episodic Return: 7.23
# ------------------------------------------------------
#
#
# -------------------- Episode #30 --------------------
# Episodic Length: 9
# Episodic Return: 9.0
# ------------------------------------------------------
#
#
# -------------------- Episode #31 --------------------
# Episodic Length: 6
# Episodic Return: -0.68
# ------------------------------------------------------
#
#
# -------------------- Episode #32 --------------------
# Episodic Length: 10
# Episodic Return: 10.0
# ------------------------------------------------------
#
#
# -------------------- Episode #33 --------------------
# Episodic Length: 10
# Episodic Return: -0.83
# ------------------------------------------------------
#
#
# -------------------- Episode #34 --------------------
# Episodic Length: 6
# Episodic Return: -1.32
# ------------------------------------------------------
#
#
# -------------------- Episode #35 --------------------
# Episodic Length: 6
# Episodic Return: -2.32
# ------------------------------------------------------
#
#
# -------------------- Episode #36 --------------------
# Episodic Length: 10
# Episodic Return: 8.62
# ------------------------------------------------------
#
#
# -------------------- Episode #37 --------------------
# Episodic Length: 11
# Episodic Return: 8.24
# ------------------------------------------------------
#
#
# -------------------- Episode #38 --------------------
# Episodic Length: 18
# Episodic Return: 5.22
# ------------------------------------------------------
#
#
# -------------------- Episode #39 --------------------
# Episodic Length: 1
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #40 --------------------
# Episodic Length: 20
# Episodic Return: 4.55
# ------------------------------------------------------
#
#
# -------------------- Episode #41 --------------------
# Episodic Length: 7
# Episodic Return: -2.76
# ------------------------------------------------------
#
#
# -------------------- Episode #42 --------------------
# Episodic Length: 21
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #43 --------------------
# Episodic Length: 6
# Episodic Return: -1.38
# ------------------------------------------------------
#
#
# -------------------- Episode #44 --------------------
# Episodic Length: 5
# Episodic Return: -0.3
# ------------------------------------------------------
#
#
# -------------------- Episode #45 --------------------
# Episodic Length: 10
# Episodic Return: 6.68
# ------------------------------------------------------
#
#
# -------------------- Episode #46 --------------------
# Episodic Length: 16
# Episodic Return: 7.47
# ------------------------------------------------------
#
#
# -------------------- Episode #47 --------------------
# Episodic Length: 24
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #48 --------------------
# Episodic Length: 5
# Episodic Return: -0.58
# ------------------------------------------------------
#
#
# -------------------- Episode #49 --------------------
# Episodic Length: 7
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #50 --------------------
# Episodic Length: 9
# Episodic Return: -3.45
# ------------------------------------------------------
#
#
# -------------------- Episode #51 --------------------
# Episodic Length: 13
# Episodic Return: 5.53
# ------------------------------------------------------
#
#
# -------------------- Episode #52 --------------------
# Episodic Length: 7
# Episodic Return: -0.32
# ------------------------------------------------------
#
#
# -------------------- Episode #53 --------------------
# Episodic Length: 5
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #54 --------------------
# Episodic Length: 6
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #55 --------------------
# Episodic Length: 9
# Episodic Return: -3.52
# ------------------------------------------------------
#
#
# -------------------- Episode #56 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #57 --------------------
# Episodic Length: 7
# Episodic Return: -1.44
# ------------------------------------------------------
#
#
# -------------------- Episode #58 --------------------
# Episodic Length: 5
# Episodic Return: -1.68
# ------------------------------------------------------
#
#
# -------------------- Episode #59 --------------------
# Episodic Length: 1
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #60 --------------------
# Episodic Length: 16
# Episodic Return: 6.22
# ------------------------------------------------------
#
#
# -------------------- Episode #61 --------------------
# Episodic Length: 7
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #62 --------------------
# Episodic Length: 6
# Episodic Return: -1.32
# ------------------------------------------------------
#
#
# -------------------- Episode #63 --------------------
# Episodic Length: 21
# Episodic Return: 5.52
# ------------------------------------------------------
#
#
# -------------------- Episode #64 --------------------
# Episodic Length: 9
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #65 --------------------
# Episodic Length: 24
# Episodic Return: 5.63
# ------------------------------------------------------
#
#
# -------------------- Episode #66 --------------------
# Episodic Length: 24
# Episodic Return: 4.46
# ------------------------------------------------------
#
#
# -------------------- Episode #67 --------------------
# Episodic Length: 8
# Episodic Return: -2.75
# ------------------------------------------------------
#
#
# -------------------- Episode #68 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #69 --------------------
# Episodic Length: 7
# Episodic Return: -0.37
# ------------------------------------------------------
#
#
# -------------------- Episode #70 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #71 --------------------
# Episodic Length: 9
# Episodic Return: 9.0
# ------------------------------------------------------
#
#
# -------------------- Episode #72 --------------------
# Episodic Length: 7
# Episodic Return: -1.38
# ------------------------------------------------------
#
#
# -------------------- Episode #73 --------------------
# Episodic Length: 10
# Episodic Return: 8.62
# ------------------------------------------------------
#
#
# -------------------- Episode #74 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #75 --------------------
# Episodic Length: 6
# Episodic Return: -1.38
# ------------------------------------------------------
#
#
# -------------------- Episode #76 --------------------
# Episodic Length: 26
# Episodic Return: 2.9
# ------------------------------------------------------
#
#
# -------------------- Episode #77 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #78 --------------------
# Episodic Length: 15
# Episodic Return: 5.81
# ------------------------------------------------------
#
#
# -------------------- Episode #79 --------------------
# Episodic Length: 15
# Episodic Return: 7.0
# ------------------------------------------------------
#
#
# -------------------- Episode #80 --------------------
# Episodic Length: 6
# Episodic Return: -3.63
# ------------------------------------------------------
#
#
# -------------------- Episode #81 --------------------
# Episodic Length: 13
# Episodic Return: 6.68
# ------------------------------------------------------
#
#
# -------------------- Episode #82 --------------------
# Episodic Length: 4
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #83 --------------------
# Episodic Length: 10
# Episodic Return: 7.56
# ------------------------------------------------------
#
#
# -------------------- Episode #84 --------------------
# Episodic Length: 13
# Episodic Return: -2.89
# ------------------------------------------------------
#
#
# -------------------- Episode #85 --------------------
# Episodic Length: 10
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #86 --------------------
# Episodic Length: 7
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #87 --------------------
# Episodic Length: 7
# Episodic Return: -2.51
# ------------------------------------------------------
#
#
# -------------------- Episode #88 --------------------
# Episodic Length: 21
# Episodic Return: 6.09
# ------------------------------------------------------
#
#
# -------------------- Episode #89 --------------------
# Episodic Length: 8
# Episodic Return: -0.37
# ------------------------------------------------------
#
#
# -------------------- Episode #90 --------------------
# Episodic Length: 6
# Episodic Return: -2.45
# ------------------------------------------------------
#
#
# -------------------- Episode #91 --------------------
# Episodic Length: 6
# Episodic Return: -2.03
# ------------------------------------------------------
#
#
# -------------------- Episode #92 --------------------
# Episodic Length: 14
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #93 --------------------
# Episodic Length: 6
# Episodic Return: -3.63
# ------------------------------------------------------
#
#
# -------------------- Episode #94 --------------------
# Episodic Length: 7
# Episodic Return: -1.45
# ------------------------------------------------------
#
#
# -------------------- Episode #95 --------------------
# Episodic Length: 7
# Episodic Return: -2.74
# ------------------------------------------------------
#
#
# -------------------- Episode #96 --------------------
# Episodic Length: 17
# Episodic Return: 5.64
# ------------------------------------------------------
#
#
# -------------------- Episode #97 --------------------
# Episodic Length: 17
# Episodic Return: -4.4
# ------------------------------------------------------
#
#
# -------------------- Episode #98 --------------------
# Episodic Length: 27
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #99 --------------------
# Episodic Length: 6
# Episodic Return: -1.45
# ------------------------------------------------------
#
#
# -------------------- Episode #100 --------------------
# Episodic Length: 12
# Episodic Return: 5.66
# ------------------------------------------------------
#
#
# -------------------- Episode #101 --------------------
# Episodic Length: 13
# Episodic Return: 7.0
# ------------------------------------------------------
#
#
# -------------------- Episode #102 --------------------
# Episodic Length: 9
# Episodic Return: 9.0
# ------------------------------------------------------
#
#
# -------------------- Episode #103 --------------------
# Episodic Length: 13
# Episodic Return: 6.46
# ------------------------------------------------------
#
#
# -------------------- Episode #104 --------------------
# Episodic Length: 23
# Episodic Return: 4.11
# ------------------------------------------------------
#
#
# -------------------- Episode #105 --------------------
# Episodic Length: 12
# Episodic Return: 6.3
# ------------------------------------------------------
#
#
# -------------------- Episode #106 --------------------
# Episodic Length: 24
# Episodic Return: 5.53
# ------------------------------------------------------
#
#
# -------------------- Episode #107 --------------------
# Episodic Length: 5
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #108 --------------------
# Episodic Length: 13
# Episodic Return: 6.46
# ------------------------------------------------------
#
#
# -------------------- Episode #109 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #110 --------------------
# Episodic Length: 15
# Episodic Return: 6.02
# ------------------------------------------------------
#
#
# -------------------- Episode #111 --------------------
# Episodic Length: 12
# Episodic Return: 5.87
# ------------------------------------------------------
#
#
# -------------------- Episode #112 --------------------
# Episodic Length: 11
# Episodic Return: 6.25
# ------------------------------------------------------
#
#
# -------------------- Episode #113 --------------------
# Episodic Length: 17
# Episodic Return: 8.08
# ------------------------------------------------------
#
#
# -------------------- Episode #114 --------------------
# Episodic Length: 24
# Episodic Return: -4.45
# ------------------------------------------------------
#
#
# -------------------- Episode #115 --------------------
# Episodic Length: 7
# Episodic Return: -3.69
# ------------------------------------------------------
#
#
# -------------------- Episode #116 --------------------
# Episodic Length: 5
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #117 --------------------
# Episodic Length: 6
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #118 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #119 --------------------
# Episodic Length: 12
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #120 --------------------
# Episodic Length: 10
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #121 --------------------
# Episodic Length: 25
# Episodic Return: 6.46
# ------------------------------------------------------
#
#
# -------------------- Episode #122 --------------------
# Episodic Length: 7
# Episodic Return: -0.37
# ------------------------------------------------------
#
#
# -------------------- Episode #123 --------------------
# Episodic Length: 15
# Episodic Return: 3.72
# ------------------------------------------------------
#
#
# -------------------- Episode #124 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #125 --------------------
# Episodic Length: 13
# Episodic Return: 6.52
# ------------------------------------------------------
#
#
# -------------------- Episode #126 --------------------
# Episodic Length: 19
# Episodic Return: -4.45
# ------------------------------------------------------
#
#
# -------------------- Episode #127 --------------------
# Episodic Length: 2
# Episodic Return: -3.82
# ------------------------------------------------------
#
#
# -------------------- Episode #128 --------------------
# Episodic Length: 7
# Episodic Return: -0.45
# ------------------------------------------------------
#
#
# -------------------- Episode #129 --------------------
# Episodic Length: 6
# Episodic Return: -2.44
# ------------------------------------------------------
#
#
# -------------------- Episode #130 --------------------
# Episodic Length: 7
# Episodic Return: -3.36
# ------------------------------------------------------
#
#
# -------------------- Episode #131 --------------------
# Episodic Length: 6
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #132 --------------------
# Episodic Length: 32
# Episodic Return: 3.6
# ------------------------------------------------------
#
#
# -------------------- Episode #133 --------------------
# Episodic Length: 18
# Episodic Return: 5.17
# ------------------------------------------------------
#
#
# -------------------- Episode #134 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #135 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #136 --------------------
# Episodic Length: 12
# Episodic Return: 6.86
# ------------------------------------------------------
#
#
# -------------------- Episode #137 --------------------
# Episodic Length: 7
# Episodic Return: -3.46
# ------------------------------------------------------
#
#
# -------------------- Episode #138 --------------------
# Episodic Length: 22
# Episodic Return: 3.16
# ------------------------------------------------------
#
#
# -------------------- Episode #139 --------------------
# Episodic Length: 19
# Episodic Return: -3.9
# ------------------------------------------------------
#
#
# -------------------- Episode #140 --------------------
# Episodic Length: 15
# Episodic Return: 4.17
# ------------------------------------------------------
#
#
# -------------------- Episode #141 --------------------
# Episodic Length: 35
# Episodic Return: 6.0
# ------------------------------------------------------
#
#
# -------------------- Episode #142 --------------------
# Episodic Length: 20
# Episodic Return: 4.69
# ------------------------------------------------------
#
#
# -------------------- Episode #143 --------------------
# Episodic Length: 5
# Episodic Return: -2.22
# ------------------------------------------------------
#
#
# -------------------- Episode #144 --------------------
# Episodic Length: 17
# Episodic Return: 6.52
# ------------------------------------------------------
#
#
# -------------------- Episode #145 --------------------
# Episodic Length: 8
# Episodic Return: -2.46
# ------------------------------------------------------
#
#
# -------------------- Episode #146 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #147 --------------------
# Episodic Length: 9
# Episodic Return: -2.44
# ------------------------------------------------------
#
#
# -------------------- Episode #148 --------------------
# Episodic Length: 17
# Episodic Return: 4.78
# ------------------------------------------------------
#
#
# -------------------- Episode #149 --------------------
# Episodic Length: 17
# Episodic Return: -4.7
# ------------------------------------------------------
#
#
# -------------------- Episode #150 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #151 --------------------
# Episodic Length: 11
# Episodic Return: 9.62
# ------------------------------------------------------
#
#
# -------------------- Episode #152 --------------------
# Episodic Length: 22
# Episodic Return: 3.49
# ------------------------------------------------------
#
#
# -------------------- Episode #153 --------------------
# Episodic Length: 11
# Episodic Return: 7.56
# ------------------------------------------------------
#
#
# -------------------- Episode #154 --------------------
# Episodic Length: 29
# Episodic Return: 5.09
# ------------------------------------------------------
#
#
# -------------------- Episode #155 --------------------
# Episodic Length: 13
# Episodic Return: 5.8
# ------------------------------------------------------
#
#
# -------------------- Episode #156 --------------------
# Episodic Length: 8
# Episodic Return: -1.44
# ------------------------------------------------------
#
#
# -------------------- Episode #157 --------------------
# Episodic Length: 5
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #158 --------------------
# Episodic Length: 5
# Episodic Return: -3.43
# ------------------------------------------------------
#
#
# -------------------- Episode #159 --------------------
# Episodic Length: 14
# Episodic Return: 8.0
# ------------------------------------------------------
#
#
# -------------------- Episode #160 --------------------
# Episodic Length: 8
# Episodic Return: -1.45
# ------------------------------------------------------
#
#
# -------------------- Episode #161 --------------------
# Episodic Length: 9
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #162 --------------------
# Episodic Length: 7
# Episodic Return: -2.51
# ------------------------------------------------------
#
#
# -------------------- Episode #163 --------------------
# Episodic Length: 14
# Episodic Return: 7.46
# ------------------------------------------------------
#
#
# -------------------- Episode #164 --------------------
# Episodic Length: 13
# Episodic Return: 3.24
# ------------------------------------------------------
#
#
# -------------------- Episode #165 --------------------
# Episodic Length: 6
# Episodic Return: -2.26
# ------------------------------------------------------
#
#
# -------------------- Episode #166 --------------------
# Episodic Length: 15
# Episodic Return: 3.42
# ------------------------------------------------------
#
#
# -------------------- Episode #167 --------------------
# Episodic Length: 15
# Episodic Return: -1.53
# ------------------------------------------------------
#
#
# -------------------- Episode #168 --------------------
# Episodic Length: 13
# Episodic Return: 7.54
# ------------------------------------------------------
#
#
# -------------------- Episode #169 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #170 --------------------
# Episodic Length: 22
# Episodic Return: 5.01
# ------------------------------------------------------
#
#
# -------------------- Episode #171 --------------------
# Episodic Length: 10
# Episodic Return: 8.62
# ------------------------------------------------------
#
#
# -------------------- Episode #172 --------------------
# Episodic Length: 15
# Episodic Return: 6.09
# ------------------------------------------------------
#
#
# -------------------- Episode #173 --------------------
# Episodic Length: 4
# Episodic Return: -1.58
# ------------------------------------------------------
#
#
# -------------------- Episode #174 --------------------
# Episodic Length: 16
# Episodic Return: 6.46
# ------------------------------------------------------
#
#
# -------------------- Episode #175 --------------------
# Episodic Length: 6
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #176 --------------------
# Episodic Length: 28
# Episodic Return: 3.85
# ------------------------------------------------------
#
#
# -------------------- Episode #177 --------------------
# Episodic Length: 31
# Episodic Return: -3.53
# ------------------------------------------------------
#
#
# -------------------- Episode #178 --------------------
# Episodic Length: 23
# Episodic Return: 4.47
# ------------------------------------------------------
#
#
# -------------------- Episode #179 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #180 --------------------
# Episodic Length: 14
# Episodic Return: 6.52
# ------------------------------------------------------
#
#
# -------------------- Episode #181 --------------------
# Episodic Length: 17
# Episodic Return: 6.22
# ------------------------------------------------------
#
#
# -------------------- Episode #182 --------------------
# Episodic Length: 11
# Episodic Return: 6.63
# ------------------------------------------------------
#
#
# -------------------- Episode #183 --------------------
# Episodic Length: 17
# Episodic Return: 4.78
# ------------------------------------------------------
#
#
# -------------------- Episode #184 --------------------
# Episodic Length: 10
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #185 --------------------
# Episodic Length: 15
# Episodic Return: 6.17
# ------------------------------------------------------
#
#
# -------------------- Episode #186 --------------------
# Episodic Length: 5
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #187 --------------------
# Episodic Length: 4
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #188 --------------------
# Episodic Length: 11
# Episodic Return: 10.0
# ------------------------------------------------------
#
#
# -------------------- Episode #189 --------------------
# Episodic Length: 8
# Episodic Return: 8.0
# ------------------------------------------------------
#
#
# -------------------- Episode #190 --------------------
# Episodic Length: 6
# Episodic Return: -2.64
# ------------------------------------------------------
#
#
# -------------------- Episode #191 --------------------
# Episodic Length: 7
# Episodic Return: -0.38
# ------------------------------------------------------
#
#
# -------------------- Episode #192 --------------------
# Episodic Length: 18
# Episodic Return: 4.78
# ------------------------------------------------------
#
#
# -------------------- Episode #193 --------------------
# Episodic Length: 9
# Episodic Return: -2.54
# ------------------------------------------------------
#
#
# -------------------- Episode #194 --------------------
# Episodic Length: 5
# Episodic Return: -1.68
# ------------------------------------------------------
#
#
# -------------------- Episode #195 --------------------
# Episodic Length: 16
# Episodic Return: -1.72
# ------------------------------------------------------
#
#
# -------------------- Episode #196 --------------------
# Episodic Length: 21
# Episodic Return: 5.58
# ------------------------------------------------------
#
#
# -------------------- Episode #197 --------------------
# Episodic Length: 26
# Episodic Return: 5.62
# ------------------------------------------------------
#
#
# -------------------- Episode #198 --------------------
# Episodic Length: 9
# Episodic Return: -3.45
# ------------------------------------------------------
#
#
# -------------------- Episode #199 --------------------
# Episodic Length: 11
# Episodic Return: -2.4
# ------------------------------------------------------
#
#
# -------------------- Episode #200 --------------------
# Episodic Length: 6
# Episodic Return: -3.37
# ------------------------------------------------------
#
#
# -------------------- Episode #201 --------------------
# Episodic Length: 13
# Episodic Return: 5.68
# ------------------------------------------------------
#
#
# -------------------- Episode #202 --------------------
# Episodic Length: 6
# Episodic Return: -2.44
# ------------------------------------------------------
#
#
# -------------------- Episode #203 --------------------
# Episodic Length: 7
# Episodic Return: -0.37
# ------------------------------------------------------
#
#
# -------------------- Episode #204 --------------------
# Episodic Length: 22
# Episodic Return: 5.16
# ------------------------------------------------------
#
#
# -------------------- Episode #205 --------------------
# Episodic Length: 15
# Episodic Return: 3.92
# ------------------------------------------------------
#
#
# -------------------- Episode #206 --------------------
# Episodic Length: 12
# Episodic Return: 6.1
# ------------------------------------------------------
#
#
# -------------------- Episode #207 --------------------
# Episodic Length: 28
# Episodic Return: 3.28
# ------------------------------------------------------
#
#
# -------------------- Episode #208 --------------------
# Episodic Length: 19
# Episodic Return: 5.22
# ------------------------------------------------------
#
#
# -------------------- Episode #209 --------------------
# Episodic Length: 6
# Episodic Return: -1.32
# ------------------------------------------------------
#
#
# -------------------- Episode #210 --------------------
# Episodic Length: 6
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #211 --------------------
# Episodic Length: 14
# Episodic Return: 7.1
# ------------------------------------------------------
#
#
# -------------------- Episode #212 --------------------
# Episodic Length: 16
# Episodic Return: 6.95
# ------------------------------------------------------
#
#
# -------------------- Episode #213 --------------------
# Episodic Length: 13
# Episodic Return: 7.46
# ------------------------------------------------------
#
#
# -------------------- Episode #214 --------------------
# Episodic Length: 32
# Episodic Return: -4.44
# ------------------------------------------------------
#
#
# -------------------- Episode #215 --------------------
# Episodic Length: 9
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #216 --------------------
# Episodic Length: 15
# Episodic Return: 6.46
# ------------------------------------------------------
#
#
# -------------------- Episode #217 --------------------
# Episodic Length: 9
# Episodic Return: 8.0
# ------------------------------------------------------
#
#
# -------------------- Episode #218 --------------------
# Episodic Length: 11
# Episodic Return: 7.49
# ------------------------------------------------------
#
#
# -------------------- Episode #219 --------------------
# Episodic Length: 9
# Episodic Return: 8.0
# ------------------------------------------------------
#
#
# -------------------- Episode #220 --------------------
# Episodic Length: 15
# Episodic Return: 4.65
# ------------------------------------------------------
#
#
# -------------------- Episode #221 --------------------
# Episodic Length: 7
# Episodic Return: -1.73
# ------------------------------------------------------
#
#
# -------------------- Episode #222 --------------------
# Episodic Length: 9
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #223 --------------------
# Episodic Length: 7
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #224 --------------------
# Episodic Length: 7
# Episodic Return: -0.32
# ------------------------------------------------------
#
#
# -------------------- Episode #225 --------------------
# Episodic Length: 18
# Episodic Return: 3.85
# ------------------------------------------------------
#
#
# -------------------- Episode #226 --------------------
# Episodic Length: 28
# Episodic Return: 6.55
# ------------------------------------------------------
#
#
# -------------------- Episode #227 --------------------
# Episodic Length: 5
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #228 --------------------
# Episodic Length: 21
# Episodic Return: 4.55
# ------------------------------------------------------
#
#
# -------------------- Episode #229 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #230 --------------------
# Episodic Length: 10
# Episodic Return: 7.3
# ------------------------------------------------------
#
#
# -------------------- Episode #231 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #232 --------------------
# Episodic Length: 17
# Episodic Return: 3.91
# ------------------------------------------------------
#
#
# -------------------- Episode #233 --------------------
# Episodic Length: 15
# Episodic Return: 4.54
# ------------------------------------------------------
#
#
# -------------------- Episode #234 --------------------
# Episodic Length: 6
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #235 --------------------
# Episodic Length: 5
# Episodic Return: -1.68
# ------------------------------------------------------
#
#
# -------------------- Episode #236 --------------------
# Episodic Length: 23
# Episodic Return: 3.26
# ------------------------------------------------------
#
#
# -------------------- Episode #237 --------------------
# Episodic Length: 7
# Episodic Return: 0.07
# ------------------------------------------------------
#
#
# -------------------- Episode #238 --------------------
# Episodic Length: 10
# Episodic Return: -0.54
# ------------------------------------------------------
#
#
# -------------------- Episode #239 --------------------
# Episodic Length: 11
# Episodic Return: -2.53
# ------------------------------------------------------
#
#
# -------------------- Episode #240 --------------------
# Episodic Length: 11
# Episodic Return: -1.86
# ------------------------------------------------------
#
#
# -------------------- Episode #241 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #242 --------------------
# Episodic Length: 7
# Episodic Return: -4.13
# ------------------------------------------------------
#
#
# -------------------- Episode #243 --------------------
# Episodic Length: 12
# Episodic Return: 5.84
# ------------------------------------------------------
#
#
# -------------------- Episode #244 --------------------
# Episodic Length: 11
# Episodic Return: 7.25
# ------------------------------------------------------
#
#
# -------------------- Episode #245 --------------------
# Episodic Length: 13
# Episodic Return: 5.05
# ------------------------------------------------------
#
#
# -------------------- Episode #246 --------------------
# Episodic Length: 1
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #247 --------------------
# Episodic Length: 8
# Episodic Return: -3.51
# ------------------------------------------------------
#
#
# -------------------- Episode #248 --------------------
# Episodic Length: 20
# Episodic Return: 3.9
# ------------------------------------------------------
#
#
# -------------------- Episode #249 --------------------
# Episodic Length: 9
# Episodic Return: 9.0
# ------------------------------------------------------
#
#
# -------------------- Episode #250 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #251 --------------------
# Episodic Length: 10
# Episodic Return: 10.0
# ------------------------------------------------------
#
#
# -------------------- Episode #252 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #253 --------------------
# Episodic Length: 12
# Episodic Return: -2.52
# ------------------------------------------------------
#
#
# -------------------- Episode #254 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #255 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #256 --------------------
# Episodic Length: 8
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #257 --------------------
# Episodic Length: 28
# Episodic Return: -4.44
# ------------------------------------------------------
#
#
# -------------------- Episode #258 --------------------
# Episodic Length: 5
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #259 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #260 --------------------
# Episodic Length: 14
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #261 --------------------
# Episodic Length: 6
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #262 --------------------
# Episodic Length: 13
# Episodic Return: 4.55
# ------------------------------------------------------
#
#
# -------------------- Episode #263 --------------------
# Episodic Length: 11
# Episodic Return: 6.19
# ------------------------------------------------------
#
#
# -------------------- Episode #264 --------------------
# Episodic Length: 9
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #265 --------------------
# Episodic Length: 7
# Episodic Return: -0.37
# ------------------------------------------------------
#
#
# -------------------- Episode #266 --------------------
# Episodic Length: 19
# Episodic Return: 4.1
# ------------------------------------------------------
#
#
# -------------------- Episode #267 --------------------
# Episodic Length: 7
# Episodic Return: -1.32
# ------------------------------------------------------
#
#
# -------------------- Episode #268 --------------------
# Episodic Length: 20
# Episodic Return: 5.54
# ------------------------------------------------------
#
#
# -------------------- Episode #269 --------------------
# Episodic Length: 6
# Episodic Return: -1.38
# ------------------------------------------------------
#
#
# -------------------- Episode #270 --------------------
# Episodic Length: 17
# Episodic Return: 5.09
# ------------------------------------------------------
#
#
# -------------------- Episode #271 --------------------
# Episodic Length: 6
# Episodic Return: -2.69
# ------------------------------------------------------
#
#
# -------------------- Episode #272 --------------------
# Episodic Length: 14
# Episodic Return: 6.62
# ------------------------------------------------------
#
#
# -------------------- Episode #273 --------------------
# Episodic Length: 7
# Episodic Return: -2.64
# ------------------------------------------------------
#
#
# -------------------- Episode #274 --------------------
# Episodic Length: 31
# Episodic Return: 3.57
# ------------------------------------------------------
#
#
# -------------------- Episode #275 --------------------
# Episodic Length: 13
# Episodic Return: 8.46
# ------------------------------------------------------
#
#
# -------------------- Episode #276 --------------------
# Episodic Length: 12
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #277 --------------------
# Episodic Length: 28
# Episodic Return: 6.52
# ------------------------------------------------------
#
#
# -------------------- Episode #278 --------------------
# Episodic Length: 18
# Episodic Return: 4.11
# ------------------------------------------------------
#
#
# -------------------- Episode #279 --------------------
# Episodic Length: 4
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #280 --------------------
# Episodic Length: 20
# Episodic Return: 7.46
# ------------------------------------------------------
#
#
# -------------------- Episode #281 --------------------
# Episodic Length: 17
# Episodic Return: -1.53
# ------------------------------------------------------
#
#
# -------------------- Episode #282 --------------------
# Episodic Length: 10
# Episodic Return: 6.3
# ------------------------------------------------------
#
#
# -------------------- Episode #283 --------------------
# Episodic Length: 10
# Episodic Return: 7.55
# ------------------------------------------------------
#
#
# -------------------- Episode #284 --------------------
# Episodic Length: 11
# Episodic Return: 8.31
# ------------------------------------------------------
#
#
# -------------------- Episode #285 --------------------
# Episodic Length: 5
# Episodic Return: -3.37
# ------------------------------------------------------
#
#
# -------------------- Episode #286 --------------------
# Episodic Length: 15
# Episodic Return: 5.21
# ------------------------------------------------------
#
#
# -------------------- Episode #287 --------------------
# Episodic Length: 16
# Episodic Return: 4.68
# ------------------------------------------------------
#
#
# -------------------- Episode #288 --------------------
# Episodic Length: 11
# Episodic Return: 7.54
# ------------------------------------------------------
#
#
# -------------------- Episode #289 --------------------
# Episodic Length: 7
# Episodic Return: -2.45
# ------------------------------------------------------
#
#
# -------------------- Episode #290 --------------------
# Episodic Length: 17
# Episodic Return: 5.22
# ------------------------------------------------------
#
#
# -------------------- Episode #291 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #292 --------------------
# Episodic Length: 9
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #293 --------------------
# Episodic Length: 10
# Episodic Return: 8.62
# ------------------------------------------------------
#
#
# -------------------- Episode #294 --------------------
# Episodic Length: 14
# Episodic Return: 0.02
# ------------------------------------------------------
#
#
# -------------------- Episode #295 --------------------
# Episodic Length: 14
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #296 --------------------
# Episodic Length: 13
# Episodic Return: 6.18
# ------------------------------------------------------
#
#
# -------------------- Episode #297 --------------------
# Episodic Length: 5
# Episodic Return: -1.38
# ------------------------------------------------------
#
#
# -------------------- Episode #298 --------------------
# Episodic Length: 22
# Episodic Return: 5.04
# ------------------------------------------------------
#
#
# -------------------- Episode #299 --------------------
# Episodic Length: 12
# Episodic Return: 6.17
# ------------------------------------------------------
#
#
# -------------------- Episode #300 --------------------
# Episodic Length: 9
# Episodic Return: 7.63
# ------------------------------------------------------
#
#
# -------------------- Episode #301 --------------------
# Episodic Length: 19
# Episodic Return: -3.09
# ------------------------------------------------------
#
#
# -------------------- Episode #302 --------------------
# Episodic Length: 8
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #303 --------------------
# Episodic Length: 7
# Episodic Return: -0.32
# ------------------------------------------------------
#
#
# -------------------- Episode #304 --------------------
# Episodic Length: 9
# Episodic Return: -2.44
# ------------------------------------------------------
#
#
# -------------------- Episode #305 --------------------
# Episodic Length: 14
# Episodic Return: -3.45
# ------------------------------------------------------
#
#
# -------------------- Episode #306 --------------------
# Episodic Length: 6
# Episodic Return: 1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #307 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #308 --------------------
# Episodic Length: 20
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #309 --------------------
# Episodic Length: 23
# Episodic Return: 4.09
# ------------------------------------------------------
#
#
# -------------------- Episode #310 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #311 --------------------
# Episodic Length: 17
# Episodic Return: 5.53
# ------------------------------------------------------
#
#
# -------------------- Episode #312 --------------------
# Episodic Length: 9
# Episodic Return: -3.32
# ------------------------------------------------------
#
#
# -------------------- Episode #313 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #314 --------------------
# Episodic Length: 8
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #315 --------------------
# Episodic Length: 19
# Episodic Return: 6.09
# ------------------------------------------------------
#
#
# -------------------- Episode #316 --------------------
# Episodic Length: 24
# Episodic Return: 3.19
# ------------------------------------------------------
#
#
# -------------------- Episode #317 --------------------
# Episodic Length: 14
# Episodic Return: 3.77
# ------------------------------------------------------
#
#
# -------------------- Episode #318 --------------------
# Episodic Length: 14
# Episodic Return: 7.23
# ------------------------------------------------------
#
#
# -------------------- Episode #319 --------------------
# Episodic Length: 18
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #320 --------------------
# Episodic Length: 6
# Episodic Return: -1.73
# ------------------------------------------------------
#
#
# -------------------- Episode #321 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #322 --------------------
# Episodic Length: 5
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #323 --------------------
# Episodic Length: 9
# Episodic Return: -3.45
# ------------------------------------------------------
#
#
# -------------------- Episode #324 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #325 --------------------
# Episodic Length: 14
# Episodic Return: 8.46
# ------------------------------------------------------
#
#
# -------------------- Episode #326 --------------------
# Episodic Length: 10
# Episodic Return: 10.0
# ------------------------------------------------------
#
#
# -------------------- Episode #327 --------------------
# Episodic Length: 13
# Episodic Return: 5.22
# ------------------------------------------------------
#
#
# -------------------- Episode #328 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #329 --------------------
# Episodic Length: 15
# Episodic Return: 9.0
# ------------------------------------------------------
#
#
# ...
#
#
# -------------------- Episode #751 --------------------
# Episodic Length: 25
# Episodic Return: 3.29
# ------------------------------------------------------
#
#
# -------------------- Episode #752 --------------------
# Episodic Length: 7
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #753 --------------------
# Episodic Length: 17
# Episodic Return: 4.76
# ------------------------------------------------------
#
#
# -------------------- Episode #754 --------------------
# Episodic Length: 26
# Episodic Return: -4.0
# ------------------------------------------------------
#
#
# -------------------- Episode #755 --------------------
# Episodic Length: 10
# Episodic Return: 8.63
# ------------------------------------------------------
#
#
# -------------------- Episode #756 --------------------
# Episodic Length: 7
# Episodic Return: -1.45
# ------------------------------------------------------
#
#
# -------------------- Episode #757 --------------------
# Episodic Length: 23
# Episodic Return: 2.79
# ------------------------------------------------------
#
#
# -------------------- Episode #758 --------------------
# Episodic Length: 11
# Episodic Return: -4.3
# ------------------------------------------------------
#
#
# -------------------- Episode #759 --------------------
# Episodic Length: 10
# Episodic Return: -3.51
# ------------------------------------------------------
#
#
# -------------------- Episode #760 --------------------
# Episodic Length: 10
# Episodic Return: -3.46
# ------------------------------------------------------
#
#
# -------------------- Episode #761 --------------------
# Episodic Length: 17
# Episodic Return: 5.46
# ------------------------------------------------------
#
#
# -------------------- Episode #762 --------------------
# Episodic Length: 8
# Episodic Return: -1.44
# ------------------------------------------------------
#
#
# -------------------- Episode #763 --------------------
# Episodic Length: 7
# Episodic Return: -1.32
# ------------------------------------------------------
#
#
# -------------------- Episode #764 --------------------
# Episodic Length: 5
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #765 --------------------
# Episodic Length: 6
# Episodic Return: -1.44
# ------------------------------------------------------
#
#
# -------------------- Episode #766 --------------------
# Episodic Length: 11
# Episodic Return: 6.12
# ------------------------------------------------------
#
#
# -------------------- Episode #767 --------------------
# Episodic Length: 7
# Episodic Return: 1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #768 --------------------
# Episodic Length: 6
# Episodic Return: -2.74
# ------------------------------------------------------
#
#
# -------------------- Episode #769 --------------------
# Episodic Length: 10
# Episodic Return: 7.3
# ------------------------------------------------------
#
#
# -------------------- Episode #770 --------------------
# Episodic Length: 5
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #771 --------------------
# Episodic Length: 18
# Episodic Return: 4.8
# ------------------------------------------------------
#
#
# -------------------- Episode #772 --------------------
# Episodic Length: 13
# Episodic Return: 8.55
# ------------------------------------------------------
#
#
# -------------------- Episode #773 --------------------
# Episodic Length: 10
# Episodic Return: 8.62
# ------------------------------------------------------
#
#
# -------------------- Episode #774 --------------------
# Episodic Length: 6
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #775 --------------------
# Episodic Length: 6
# Episodic Return: -1.32
# ------------------------------------------------------
#
#
# -------------------- Episode #776 --------------------
# Episodic Length: 6
# Episodic Return: -3.43
# ------------------------------------------------------
#
#
# -------------------- Episode #777 --------------------
# Episodic Length: 24
# Episodic Return: 5.62
# ------------------------------------------------------
#
#
# -------------------- Episode #778 --------------------
# Episodic Length: 4
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #779 --------------------
# Episodic Length: 31
# Episodic Return: 3.81
# ------------------------------------------------------
#
#
# -------------------- Episode #780 --------------------
# Episodic Length: 15
# Episodic Return: 5.49
# ------------------------------------------------------
#
#
# -------------------- Episode #781 --------------------
# Episodic Length: 9
# Episodic Return: -4.45
# ------------------------------------------------------
#
#
# -------------------- Episode #782 --------------------
# Episodic Length: 14
# Episodic Return: 7.1
# ------------------------------------------------------
#
#
# -------------------- Episode #783 --------------------
# Episodic Length: 12
# Episodic Return: 5.1
# ------------------------------------------------------
#
#
# -------------------- Episode #784 --------------------
# Episodic Length: 6
# Episodic Return: -1.21
# ------------------------------------------------------
#
#
# -------------------- Episode #785 --------------------
# Episodic Length: 11
# Episodic Return: -3.46
# ------------------------------------------------------
#
#
# -------------------- Episode #786 --------------------
# Episodic Length: 9
# Episodic Return: -2.54
# ------------------------------------------------------
#
#
# -------------------- Episode #787 --------------------
# Episodic Length: 6
# Episodic Return: -3.32
# ------------------------------------------------------
#
#
# -------------------- Episode #788 --------------------
# Episodic Length: 5
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #789 --------------------
# Episodic Length: 11
# Episodic Return: 6.62
# ------------------------------------------------------
#
#
# -------------------- Episode #790 --------------------
# Episodic Length: 7
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #791 --------------------
# Episodic Length: 4
# Episodic Return: -3.0
# ------------------------------------------------------
#
#
# -------------------- Episode #792 --------------------
# Episodic Length: 20
# Episodic Return: 7.0
# ------------------------------------------------------
#
#
# -------------------- Episode #793 --------------------
# Episodic Length: 9
# Episodic Return: 7.62
# ------------------------------------------------------
#
#
# -------------------- Episode #794 --------------------
# Episodic Length: 7
# Episodic Return: -0.32
# ------------------------------------------------------
#
#
# -------------------- Episode #795 --------------------
# Episodic Length: 10
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #796 --------------------
# Episodic Length: 6
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #797 --------------------
# Episodic Length: 11
# Episodic Return: 6.25
# ------------------------------------------------------
#
#
# -------------------- Episode #798 --------------------
# Episodic Length: 17
# Episodic Return: 8.46
# ------------------------------------------------------
#
#
# -------------------- Episode #799 --------------------
# Episodic Length: 11
# Episodic Return: -2.47
# ------------------------------------------------------
#
#
# -------------------- Episode #800 --------------------
# Episodic Length: 6
# Episodic Return: 0.7
# ------------------------------------------------------
#
#
# -------------------- Episode #801 --------------------
# Episodic Length: 6
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #802 --------------------
# Episodic Length: 11
# Episodic Return: 5.83
# ------------------------------------------------------
#
#
# -------------------- Episode #803 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #804 --------------------
# Episodic Length: 20
# Episodic Return: 6.02
# ------------------------------------------------------
#
#
# -------------------- Episode #805 --------------------
# Episodic Length: 4
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #806 --------------------
# Episodic Length: 15
# Episodic Return: 6.54
# ------------------------------------------------------
#
#
# -------------------- Episode #807 --------------------
# Episodic Length: 18
# Episodic Return: 4.55
# ------------------------------------------------------
#
#
# -------------------- Episode #808 --------------------
# Episodic Length: 31
# Episodic Return: 5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #809 --------------------
# Episodic Length: 18
# Episodic Return: -3.53
# ------------------------------------------------------
#
#
# -------------------- Episode #810 --------------------
# Episodic Length: 32
# Episodic Return: 3.72
# ------------------------------------------------------
#
#
# -------------------- Episode #811 --------------------
# Episodic Length: 6
# Episodic Return: -3.43
# ------------------------------------------------------
#
#
# -------------------- Episode #812 --------------------
# Episodic Length: 14
# Episodic Return: 6.22
# ------------------------------------------------------
#
#
# -------------------- Episode #813 --------------------
# Episodic Length: 9
# Episodic Return: -4.37
# ------------------------------------------------------
#
#
# -------------------- Episode #814 --------------------
# Episodic Length: 5
# Episodic Return: -1.67
# ------------------------------------------------------
#
#
# -------------------- Episode #815 --------------------
# Episodic Length: 7
# Episodic Return: -3.45
# ------------------------------------------------------
#
#
# -------------------- Episode #816 --------------------
# Episodic Length: 14
# Episodic Return: 6.09
# ------------------------------------------------------
#
#
# -------------------- Episode #817 --------------------
# Episodic Length: 6
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #818 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #819 --------------------
# Episodic Length: 5
# Episodic Return: -2.37
# ------------------------------------------------------
#
#
# -------------------- Episode #820 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #821 --------------------
# Episodic Length: 8
# Episodic Return: -3.08
# ------------------------------------------------------
#
#
# -------------------- Episode #822 --------------------
# Episodic Length: 10
# Episodic Return: 8.63
# ------------------------------------------------------
#
#
# -------------------- Episode #823 --------------------
# Episodic Length: 12
# Episodic Return: -2.64
# ------------------------------------------------------
#
#
# -------------------- Episode #824 --------------------
# Episodic Length: 15
# Episodic Return: -3.4
# ------------------------------------------------------
#
#
# -------------------- Episode #825 --------------------
# Episodic Length: 8
# Episodic Return: 8.0
# ------------------------------------------------------
#
#
# -------------------- Episode #826 --------------------
# Episodic Length: 9
# Episodic Return: -3.52
# ------------------------------------------------------
#
#
# -------------------- Episode #827 --------------------
# Episodic Length: 8
# Episodic Return: -1.54
# ------------------------------------------------------
#
#
# -------------------- Episode #828 --------------------
# Episodic Length: 21
# Episodic Return: 5.46
# ------------------------------------------------------
#
#
# -------------------- Episode #829 --------------------
# Episodic Length: 10
# Episodic Return: 8.62
# ------------------------------------------------------
#
#
# -------------------- Episode #830 --------------------
# Episodic Length: 10
# Episodic Return: -3.11
# ------------------------------------------------------
#
#
# -------------------- Episode #831 --------------------
# Episodic Length: 7
# Episodic Return: -2.52
# ------------------------------------------------------
#
#
# -------------------- Episode #832 --------------------
# Episodic Length: 10
# Episodic Return: -0.7
# ------------------------------------------------------
#
#
# -------------------- Episode #833 --------------------
# Episodic Length: 6
# Episodic Return: -3.52
# ------------------------------------------------------
#
#
# -------------------- Episode #834 --------------------
# Episodic Length: 10
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #835 --------------------
# Episodic Length: 5
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #836 --------------------
# Episodic Length: 7
# Episodic Return: -1.37
# ------------------------------------------------------
#
#
# -------------------- Episode #837 --------------------
# Episodic Length: 29
# Episodic Return: 3.17
# ------------------------------------------------------
#
#
# -------------------- Episode #838 --------------------
# Episodic Length: 5
# Episodic Return: -3.43
# ------------------------------------------------------
#
#
# -------------------- Episode #839 --------------------
# Episodic Length: 7
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #840 --------------------
# Episodic Length: 6
# Episodic Return: -1.0
# ------------------------------------------------------
#
#
# -------------------- Episode #841 --------------------
# Episodic Length: 15
# Episodic Return: 5.48
# ------------------------------------------------------
#
#
# -------------------- Episode #842 --------------------
# Episodic Length: 15
# Episodic Return: 4.17
# ------------------------------------------------------
#
#
# -------------------- Episode #843 --------------------
# Episodic Length: 10
# Episodic Return: 7.31
# ------------------------------------------------------
#
#
# -------------------- Episode #844 --------------------
# Episodic Length: 6
# Episodic Return: 0.0
# ------------------------------------------------------
#
#
# -------------------- Episode #845 --------------------
# Episodic Length: 14
# Episodic Return: 7.56
# ------------------------------------------------------
#
#
# -------------------- Episode #846 --------------------
# Episodic Length: 1
# Episodic Return: -5.0
# ------------------------------------------------------
#
#
# -------------------- Episode #847 --------------------
# Episodic Length: 11
# Episodic Return: 3.63
# ------------------------------------------------------
#
#
# -------------------- Episode #848 --------------------
# Episodic Length: 28
# Episodic Return: 4.1
# ------------------------------------------------------
#
#
# -------------------- Episode #849 --------------------
# Episodic Length: 10
# Episodic Return: 6.19
# ------------------------------------------------------
#
#
# -------------------- Episode #850 --------------------
# Episodic Length: 5
# Episodic Return: -2.0
# ------------------------------------------------------
#
#
# -------------------- Episode #851 --------------------
# Episodic Length: 19
# Episodic Return: 4.47
# ------------------------------------------------------
#
#
# -------------------- Episode #852 --------------------
# Episodic Length: 25
# Episodic Return: 3.9
# ------------------------------------------------------
#
#
# -------------------- Episode #853 --------------------
# Episodic Length: 10
# Episodic Return: 5.93
# ------------------------------------------------------
#
#
# -------------------- Episode #854 --------------------
# Episodic Length: 25
# Episodic Return: 5.02
# ------------------------------------------------------
